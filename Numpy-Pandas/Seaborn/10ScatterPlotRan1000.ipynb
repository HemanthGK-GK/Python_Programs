# %%
#Write a program to draw a scatter plot for random 1000 x and y coordinates
import matplotlib.pyplot as plt
from pylab import randn
X = randn(1000)
Y = randn(1000)
col=['gray']
plt.scatter(X,Y, color=col)#creating plat
plt.xlabel("X")
plt.ylabel("Y")
plt.show()#Display Plot
