# %%
# Write a program to draw a swarm plot of total bill against size for a given dataset

import matplotlib.pyplot as plt
import seaborn as sns
# Set Seaborn style
sns.set_style('whitegrid')
# Import Data
tips_dataset = sns.load_dataset("tips")

# Construct plot
sns.swarmplot(x = "size", y = "total_bill", data = tips_dataset)
plt.show()
# Out:
# C:\Users\91807\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:1296: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
